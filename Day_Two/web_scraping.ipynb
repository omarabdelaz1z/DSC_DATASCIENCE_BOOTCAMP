# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
article_ids = {
    'politics': 78,
    'accidents': 7,
    'sports': 8,
    'economics': 4
}

# %% [markdown]
# ### Getting Article URLs
# Assuming we are interested in Sport, Politics, Accidents and Economics Articles.

# %%
def get_articles_urls(article_id, page):
    """
    Given article_id and page number, we fetch all the articles' urls in that page.
    returns List of urls.
    """
    url = 'https://www.almasryalyoum.com/news/index?page=' + str(page) + '&sectionid=' + str(article_id) + '&typeid=1'
    response = requests.get(url)
    
    if not response.ok:
        return False
    
    else:
        soup = BeautifulSoup(response.text)
        list_of_news = soup.find('div', attrs={'class':'ListNews'}).findAll('div', attrs = {'class':'news'})
        
        article_urls = []
        for news in list_of_news:
            article_urls.append('https://www.almasryalyoum.com' + news.find('a')['href'])
        
        if not article_urls: 
            return False
        
        return article_urls

# %% [markdown]
# ### Getting Article Details

# %%
def get_article_details(url):
    """
    Returning various information of an article.
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    news_title = soup.title.text
    news_image = soup.find('div', attrs= {'class':'articleimg'}).find('img')['src']
    body = soup.find('div',attrs={'id':'NewsStory'})
    
    # removing unraleted text
    body.find('div',attrs={'class':'smsBoxContainer-v1'}).decompose()
    body.find('div',attrs={'class':'min_related'}).decompose()
    
    news_body = ""
    for p in body.findAll('p'):
        news_body += " " + p.text
     
    news_keywords = soup.find('meta',attrs={'name':'keywords'})['content']    
    
    news_article = {
        'news_url': url,
        'news_title': news_title,
        'news_image':news_image,
        'news_body': news_body,
        'news_keywords': news_keywords
    }
    
    return news_article

# %% [markdown]
# ### Function return a pandas DataFrame of all news of a specific section/page

# %%
def get_articles(article_id = 8, page = 2):
    """
    Return a pandas DataFrame of all news/articles in a specific page.
    """
    topic_articles = []
    urls = get_articles_urls(article_id, page)
    
    if hasattr(urls, '__iter__'):
        for url in get_articles_urls(article_id, page):
            topic_articles.append(get_article_details(url))
    
        return pd.DataFrame(topic_articles)
    else:
        return pd.DataFrame()

# %%
sports_articles = get_articles()

# %%
sports_articles
# Out:
#                                              news_url  \
# 0   https://www.almasryalyoum.com/news/details/207...
# 1   https://www.almasryalyoum.com/news/details/207...
# 2   https://www.almasryalyoum.com/news/details/207...
# 3   https://www.almasryalyoum.com/news/details/207...
# 4   https://www.almasryalyoum.com/news/details/207...
# 5   https://www.almasryalyoum.com/news/details/207...
# 6   https://www.almasryalyoum.com/news/details/207...
# 7   https://www.almasryalyoum.com/news/details/207...
# 8   https://www.almasryalyoum.com/news/details/207...
# 9   https://www.almasryalyoum.com/news/details/207...
# 10  https://www.almasryalyoum.com/news/details/207...
# 11  https://www.almasryalyoum.com/news/details/207...
# 12  https://www.almasryalyoum.com/news/details/207...
# 13  https://www.almasryalyoum.com/news/details/207...
# 14  https://www.almasryalyoum.com/news/details/207...
# 15  https://www.almasryalyoum.com/news/details/207...
# 16  https://www.almasryalyoum.com/news/details/207...
#
#                                            news_title  \
# 0   صلاح ورمضان صبحي وطاهر وعودة النني.. البدري يع...
# 1   الهلال يتصدر قائمة الأندية الأكثر متابعة على «...
# 2   معلول خارج حسابات الأهلي في مباراة طلائع الجيش...
# 3    سيد لاشين: سعيد بالتجديد للأهلي.. وهذه رسالتي...
# 4   الخطيب يجتمع مع لاعبى الأهلى قبل النهائى الإفر...
# 5   الأهلي يصرف النظر عن أسامة جلال.. وموسيماني يُ...
# 6    الاتحاد الدولي لكرة اليد يطالب المشاركين بمون...
# 7   اللجنة الأوليمبية تستقبل رئيس الاتحادين العر...
# 8   بادجي وجيرالدو خارج حسابات موسيماني  | المصري ...
# 9   قائد ليفربول: صلاح يقدم تحديات كثيرة وأداءً مذ...
# 10  بقيادة صلاح.. التشكيل المتوقع لليفربول أمام مي...
# 11  تعرّف على مواعيد مباريات دوري أبطال أوروبا | ا...
# 12  رمضان صبحي يتحدث عن رسالة للخطيب واتهامات لشوب...
# 13  مدرب وست بروميتش: رحيل حجازي صدمة لا يستطيع ال...
# 14  مرتضى منصور موجهاً اللوم لرئيس أسوان ونجمي الز...
# 15  قناة الأهلي تُعلق على «شماتة» جماهير النادي في...
# 16  شوبير يرد بقوة على رمضان صبحي ويفجر مفاجاّت جد...
#
#                                            news_image  \
# 0   https://mediaaws.almasryalyoum.com/news/large/...
# 1   https://mediaaws.almasryalyoum.com/news/large/...
# 2   https://mediaaws.almasryalyoum.com/news/large/...
# 3   https://mediaaws.almasryalyoum.com/news/large/...
# 4   https://mediaaws.almasryalyoum.com/news/large/...
# 5   https://mediaaws.almasryalyoum.com/news/large/...
# 6   https://mediaaws.almasryalyoum.com/news/large/...
# 7   https://mediaaws.almasryalyoum.com/news/large/...
# 8   https://mediaaws.almasryalyoum.com/news/large/...
# 9   https://mediaaws.almasryalyoum.com/news/large/...
# 10  https://mediaaws.almasryalyoum.com/news/large/...
# 11  https://mediaaws.almasryalyoum.com/news/large/...
# 12  https://mediaaws.almasryalyoum.com/news/large/...
# 13  https://mediaaws.almasryalyoum.com/news/large/...
# 14  https://mediaaws.almasryalyoum.com/news/large/...
# 15  https://mediaaws.almasryalyoum.com/news/large/...
# 16  https://mediaaws.almasryalyoum.com/news/large/...
#
#                                             news_body  \
# 0     أعلن الجهاز الفني لمنتخب مصر قائمة مبدئية من...
# 1     تصدر نادي الهلال السعودي قائمة الأندية العرب...
# 2     يدرس بيستو موسميانى، المدير الفنى للفريق الك...
# 3     عبر سيد لاشين، قائد فريق رجال تنس الطاولة با...
# 4     يعقد محمود الخطيب، رئيس مجلس إدارة النادى ال...
# 5     علمت «المصري اليوم» أن الأهلي صرف النظر عن ا...
# 6     أرسل الاتحاد الدولي لكرة اليد برئاسة الدكت...
# 7     زار مقر اللجنة الأوليمبية المصرية صباح اليو...
# 8     طلب بيتسو موسيماني من لجنة التعاقدات بالنادي...
# 9     تغنى جوردن هندرسون، قائد ليفربول، بما يقدمه ...
# 10    يستضيف ليفربول الإنجليزي نظيره الدنماركي ميت...
# 11    يعد، اليوم الثلاثاء يومًا حافلاً بمباريات دو...
# 12    تحدث رمضان صبحي لاعب بيراميدز للمرة الأولى ع...
# 13    قال سلافن بيليتش، مدرب وست بروميتش الإنجليزي...
# 14    وجه مرتضى منصور، رئيس مجلس إدارة نادي الزمال...
# 15    قال الاعلامي إبراهيم المنيسي، أنه تلقى العدي...
# 16    رد الاعلامي أحمد شوبير، على تصريحات رمضان، ن...
#
#                                         news_keywords
# 0   رمضان صبحي, طاهر محمد طاهر, محمد صلاح, حسام ال...
# 1   الهلال السعودي, الدوري السعودي, كأس الأمير محم...
# 2                              معلول, استبعاد, الاهلى
# 3                                الاهلى, لاشين, تجديد
# 4                               الخطيب, يجتمع, الاهلى
# 5                     موسيماني, الأهلي, الدوري المصري
# 6                               مونديال, اليد, العالم
# 7                         اللجنة, الاوليمبية, استقبال
# 8    بادجي, جيرالدو, موسيماني, أليو بادجي لاعب الأهلي
# 9                 ليفربول, محمد صلاح, جوردان هيندرسون
# 10  ليفربول, انتقال محمد صلاح إلى ليفربول, أوريجي ...
# 11  ليفربول, ميلان, إصابة محمد صلاح وخروجه من مبار...
# 12                     رمضان صبحي, الأهلي, أحمد شوبير
# 13          أحمد حجازي, الدوري الإنجليزي, ويستبروميتش
# 14  مرتضى منصور, الزمالك, أخبار الزمالك, أسوان, ال...
# 15  الأهلي, أخبار الأهلي, الدوري المصري, بيراميدز,...
# 16  شوبير, رمضان صبحي, أخبار الأهلي, النادي الأهلي...
